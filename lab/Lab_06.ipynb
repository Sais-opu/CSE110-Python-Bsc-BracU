# %% [markdown]
# # CSE110 Assignment 6
# This assignment is to guide you to solve everything you have learned so far by implementing Exceptions in Python.
#
# **<font color='red'>[MUST MAINTAIN VARIABLE NAMING CONVENTIONS FOR ALL THE TASKS]</font>**
#
# ## Write the Python code of the following problems:

# %% [markdown]
# ### Task 1
# Given a list named my_list.
# my_list=[10,20,30,40,60,100,2,5]
#
# Write a python program that takes the position as an input from the user and prints the element of that position from the list.
#
# If the user’s input position is not in the range, return an exception stating “Index out of range”.
#
# Make sure your program always prints “Program ended” at the end, no matter what happens.
#
# Hint: Use finally block
#
# **Example 1:** \
# **Input:**\
# 1\
# **Output:**\
# 20\
# Program ended
#
# =============================
#
# **Example 2:** \
# **Input:**\
# 10\
# **Output:**\
# Index out of range.\
# Program ended

# %%
#To do
#create a function.
def my_function (index_value):
    my_list = [10, 20, 30, 40, 60, 100, 2, 5]
    try:
        #indexing.
        print (my_list[index_value])
    #exceptions.
    except IndexError:
        print("Index out of range.")
    finally:
        print("Program ended.")
#taking input.
index_input = int(input("Enter position: ")) 
#function call.
my_function(index_input)
# Out:
# Enter position: 10
# Index out of range.
# Program ended.

# %% [markdown]
# ### Task 2
#
# Suppose you have a dictionary named my_dictionary containing the name of some groceries and their prices.\
# my_dictionary={“Potato”:12, “Onion”:16, “Ginger”:15, “Garlic”:12, “Tomato”:15}
#
# Now write a python program that takes the grocerie names as input from the users and shows the total price of the groceries.
#
# Some exceptions to handle:
# * Handle the exception when the given key is not present in the dictionary.
# * Handle the exception when the summation variable is not initialized.
#
# **Example 1:** \
# **Input:**\
# Potato,Onion,Ginger\
# **Output:**\
# 43
#
# =============================
#
# **Example 2:** \
# **Input:**\
# Potato,Onion,Ginger,Beef\
# **Output:**\
# Some groceries are not available in the dictionary.

# %%
#To do
#create a function.
def my_function (items):
    try:
        my_dictionary = {"Potato":12, "Onion":16, "Ginger":15, "Garlic":12, "Tomato":15}
        total_price = 0
        #using loop for counting total price.
        for index in range (len(items)):
            total_price += my_dictionary[items[index]]
        print(total_price)
    #exceptions.
    except KeyError:
        print("Some groceries are not available in the dictionary.")
    except NameError:
        print("The summation variable is not initialized.")
#taking input.       
grocerie_items = input("Enter grocerie items: ").split(",")
#function call.        
my_function(grocerie_items)
# Out:
# Enter grocerie items: Potato,Onion,Ginger
# 43

# %% [markdown]
# ### Task 3
# Write a python program that takes two lists as input from the user, multiplies the index wise elements of the two lists and adds it to a new variable. While doing the program you should handle the following exceptions:
# * Return an exception when the new variable is not declared stating “The new variable is not declared”.
# * Return an exception if an element in a list is not a number stating “The list has some non number values”.
# * Return an exception if there is an index out of bound stating “Index out of bound”.
#
# **Example 1:** \
# **Input:**\
# list_one = [1, a, 2, 4]\
# List_two =[5, 6, 7, 8]\
# **Output:**\
# The list has some non number values
#
# =================
#
# **Example 2:** \
# **Input:**\
# list_one=[1, 2, 3, 4, 5]\
# list_two=[1, 2, 3, 4]\
# **Output:**\
# Index out of bound
#
# =================
#
# **Example 3:** \
# **Input:**\
# list_one=[1,2,3,4]\
# list_two=[5,6,7,8]\
# **Output:**\
# 70

# %%
#To do
#create a function.
def my_function (first_list,second_list,length):
    try:
        addition_variable = 0
        #calculation.
        for index in range (length):
            addition_variable += (int(first_list[index]) * int(second_list[index]))
        print(addition_variable)
    #exceptions.
    except NameError:
        print("The new variable is not declared.")
    except ValueError:
        print("The list has some non number values.")
    except IndexError:
        print("Index out of bound.")
#taking input.
list_one = input("Enter first list: ").replace("[","").replace("]","").split(",")
list_two = input("Enter second list: ").replace("[","").replace("]","").split(",")
#checking highest length of list.
if len(list_one) > len(list_two):
    highest_length = len(list_one)
else:
    highest_length = len(list_two)
#function call.   
my_function(list_one,list_two,highest_length)
# Out:
# Enter first list: [1, 2, 3, 4, 5]
# Enter second list: [1, 2, 3, 4, s]
# The list has some non number values.

# %% [markdown]
# ### Task 4
# Write a python program that will take a string input from the user. Your task is to count the number of vowels and consonants in the string.
#
# Using try, if the number of vowels is greater than or equal to the number of consonants than raise a runtime error. Print 'Number of vowels greater/equal to consonants. Please, paraphrase'.\
# Otherwise, print 'The sentence will work'.
#
# **Note:** a,e,i,o,u are called vowels and all the other 21 english alphabets are consonants.
#
# **Example 1:** \
# **Input:**\
# 'his age is 10'\
# **Output:**\
# Number of vowels is greater/equal. Paraphrase the sentence
#
# =================
#
# **Example 2:** \
# **Input:**\
# 'he is 10 years old'\
# **Output:**\
# The sentence will work

# %%
#To do
#create a function.
def my_function (string):
    try:
        #declaring variables in one-line.
        vowels_count, consonants_count = 0, 0
        #using loop for checking vowel and consonants in the user input.
        for index in range (len(string)):
            #using ord() to check element in (a-z)
            if ord("a") <= ord(string[index]) <= ord("z"):
                if string[index] in ("a","e","i","o","u"):
                    vowels_count += 1
                else:
                    consonants_count += 1
        #checking condition for following error.
        if vowels_count >= consonants_count:
            raise RuntimeError
    except RuntimeError:
        print("Number of vowels greater/equal to consonants. Please, paraphrase")
    else:
        print("The sentence will work.")
#taking input.
string_input = input("Write a sentence: ").lower()
#function call.
my_function(string_input)
# Out:
# Write a sentence: his age is 10
# Number of vowels greater/equal to consonants. Please, paraphrase

# %% [markdown]
# ### Task 5
# Write a python program that finds the corresponding energy values from a list of frequency values which are taken as input from the user, using the formula, $E=h*f$, where h is a constant of value: 1050
#
# Exceptions to handle:
# * Make sure all elements in the lists are numbers
#
#
# **Example 1:** \
# **Input:**\
# [$2$,$3$]\
# **Output:**\
# [$2100$, $3150$]
#
# =================
#
# **Example 2:** \
# **Input:**\
# [2,boss]\
# **Output:**\
# Wrong input type

# %%
#To do
#create a function.
def my_function (values_list):
    try:
        energyValues_list = []
        #using loop for calculation [E * f].
        for index in range (len(values_list)):
            energyValues_list.append(1050 * int(values_list[index]))
        print(energyValues_list)
    #exceptions.
    except ValueError:
        print("Wrong input type.")      
#taking input.  
frequencyValues_list = input("Enter frequency values list: ").replace("[","").replace("]","").split(",")
#function call.
my_function(frequencyValues_list)
# Out:
# Enter frequency values list: [2,boss]
# Wrong input type.

# %% [markdown]
# ### Task 6
# Write a python function that will remove a given character from a sentence based on the starting and ending index of the sentence. In the place of the removed characters, add the count of the number of characters removed so far. For this program, you need to take 4 user inputs.
# * Sentence
# * Character to be removed
# * Starting index (inclusive)
# * Ending index (inclusive)
#
# Few exceptions to catch:
# * Name Error if a variable is not found. Print ‘Name Error: Variable not defined’
# * Value Error if the starting index and ending index is not an integer. Print ‘Value Error: Wrong input, please enter an integer value.’
# * Type Error when adding count in the new sentence. Print ‘Type Error: Cannot add integer value with string.’
# * Index Error if the starting and ending index is out of range. Print ‘Index Error: Index is outside the range of sentence length.’
# * For other exceptions, catch Exception. Print ‘Some other error occurred.’
#
# If no exception occurred, print the new string using else block. At the end using finally, print ‘The program execution is complete’.
#
# **Example 1:** \
# **Input:**\
# 'my python programming book'\
# 'm'\
# 2\
# 20\
# **Output:**\
# my python progra12ing book\
# The program execution is complete
#
# =================
#
# **Example 2:** \
# **Input:**\
# 'my python programming book'\
# 'm'\
# 2.5\
# 20\
# **Output:**\
# Value Error: Wrong input, please enter an integer value.\
# The program execution is complete
#
# =================
#
# **Example 3:** \
# **Input:**\
# 'my python programming book'\
# 'm'\
# 2\
# 100\
# **Output:**\
# Index Error: Index is outside the range of sentence length.\
# The program execution is complete

# %%
## To do
#create a function.
def remove_character (sentence_input,removed_character,starting_index,ending_index):
    try:
        #converting string to integer in one-line.
        starting_index, ending_index = int(starting_index), int(ending_index)
        #declaring variables in one-line.
        removedCharacter_count, sentence_part = 1, ""
        #using loop for excuting exact part of senctence.
        for index in range (starting_index,ending_index+1):
            sentence_part += sentence_input[index]
        #using loop for removing exact character from the part of senctence.
        for index in range (len(sentence_part)):
            if sentence_part[index] == removed_character:
                #using replace() to replace the removable character to the counter number.
                sentence_part = sentence_part.replace(sentence_part[index],str(removedCharacter_count),1)
                removedCharacter_count += 1
        #organizing the modified sentence.
        modified_sentence = sentence_input[0:starting_index]+sentence_part+sentence_input[ending_index+1:]
    #exceptions.
    except NameError:
        print("Name Error: Variable not defined.")
    except ValueError:
        print("Value Error: Wrong input, please enter an integer value.")
    except TypeError:
        print("Type Error: Cannot add integer value with string.")
    except IndexError:
        print("Index Error: Index is outside the range of sentence length.")
    except Exception:
        print("Some other error occurred.")
    else:
        print(modified_sentence)
    finally:
        print("The program execution is complete")
#taking input.    
first_input = input("Enter a sentence: ")
second_input = input("Enter the character to be removed: ")
third_input = input("Enter starting index: ")
fourth_input = input("Enter ending index: ")
#function call.
remove_character(first_input,second_input,third_input,fourth_input)
# Out:
# Enter a sentence: my python programming book
# Enter the character to be removed: m
# Enter starting index: 2
# Enter ending index: 20
# my python progra12ing book
# The program execution is complete

# %% [markdown]
# ### Task 7
# Read a **file** from the user which contains the  name and salary of employees. Convert that to a dictionary where the key is the name of each employee and value is the salary of that employee. Then find the total cost for the company that it needs to pay through employees’ salary. Print the dictionary and sum if no exception occurs.
#
# Exception to handle:
# * check whether file is actually there
# * Check whether the salary in each line is a number or not.
# * Raise error if there are extra numbers or names
#
# **Example 1:** \
# **Input:**\
# Saadat 100\
# Farzad 200\
# Atef 300\
# **Output:**\
# dict={Saadat : 100, Farzad : 200, Atef : 300}\
# Sum = 600
#
# =================
#
# **Example 2:** \
# **Input:**\
# Saadat 100\
# Farzad 200\
# Atef 300\
# John\
# **Output:**\
# Extra Statement

# %%
#To do
"""In this file I took as input:
        Saadat 100
        Farzad 200
        Atef 300"""
file_dict,sum_values = {}, 0
try:
    #reading a file with with() function.
    with open("user_input_file.txt")as file:
        for line in file.readlines():
            #checking how many words in online.(using strip() and split() function.)
            if len(line.strip().split(" ")) == 2:
                #tuple unpacking.
                key,value = line.strip().split(" ")
            else:
                #raising exception.
                raise Exception
            #calculate.
            sum_values += int(value)
            #updating the declared dictionary with data in line.
            file_dict.update({key:int(value)})
#exceptions.
except FileNotFoundError:
    print("File is not actually there.")
except ValueError:
    print("Salary in line is not a integer number.")
except Exception:
    print("Extra Statement.")
else:
    print(f"dict={file_dict}")
    print(f"Sum = {sum_values}")
# Out:
# dict={'Saadat': 100, 'Farzad': 200, 'Atef': 300}
# Sum = 600

# %% [markdown]
# ### Task 8
# Imagine Salman Khan is going to the sets of a new movie. He decides to cycle everyday on his way to the sets. For that he uses a distance calculator which finds the distance based on the present day's date, which is asked as an input from the user. You should first take the day and then the month as your inputs.
# The inputs should be stored in variables named `day` and `month` The distance calculator uses the following formulae to calculate a number which dictates the number of kilometers he must cycle on his way to work.
#
# Exceptions to handle:\
# -Check for 0 division error exception\
# -Type error exception when taking date as input\
# -Value error exception, as day can not be greater than 31 and month can not be greater than 12
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Distance = |if day<10, `5+(day*2)/month`\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; |else, `3+(day/month)`
#
#
# **Example 1:** \
# **Input:**\
# 3\
# 5\
# **Output:**\
# 6.2 kilometres
#
# =================
#
# **Example 2:** \
# **Input:**\
# 2\
# 0\
# **Output:**\
# 0 is not a valid month
#
# **Example 3:** \
# **Input:**\
# 35\
# 12\
# **Output:**\
# 35 is not a valid day of any month
#
#
# **Example 4:** \
# **Input:**\
# Hello\
# 12\
# **Output:**\
# Please do not enter any string as input
#
#
# **Example 5:** \
# **Input:**\
# 15\
# 12\
# **Output:**\
# 4.25 kilometres

# %%
#To do
#create a function.
def distance_calculation (day,month):
    try:
        #checking condition and raising error if the condition satisfied.
        #using isdigit() built in function for raising TypeError.
        if not day.isdigit() or not month.isdigit():
            raise TypeError
        #converting string to integer.
        day,month = int(day),int(month)
        #checking condition and raising error if the condition satisfied.
        if day > 31 or month > 12:
            #raising the following error.
            raise ValueError   
        else:
            #calculate.
            if day<10:
                distance = (5 + (day * 2)) / month
            else:
                distance = 3 + (day / month)
    #exceptions.   
    except ZeroDivisionError:
        print("0 is not a valid month.")
    except TypeError:
        print("Please do not enter any string as input.")
    except ValueError:
        #checking condition for printing.
        if int(day) > 31:
            print(f"{day} is not a valid day of any month.")
        else:
            print(f"{month} is not a valid month.")
    else:
        print(f"{distance} kilometres")
#taking input.        
day_input = input("Enter day: ")
month_input = input("Enter month: ")
#function call.       
distance_calculation(day_input,month_input)
# Out:
# Enter day: 12
# Enter month: 13
# 13 is not a valid month.

# %% [markdown]
# ### Task 9
# Write a python program to make a calculator. The user must input a string consisting of a number, operator and another number separated by white spaces.
# * If the user’s input does not contain 3 elements, raise an exception error stating “Input does not contain 3 elements/Wrong operator”.
# * If the user inputs any other values except numbers in first and third position of the input, raise value error exception stating “Input does not contain numbers.”
# * If the user does not input ‘+’ or ‘-’ or ’/’ or ‘*’ or ‘%’ in second position of the input, again raise an exception stating “Input does not contain 3 elements/Wrong operator”.
# * In case of division, also handle divide by zero exception.
#
# If all the inputs are correct, calculate the result and print the value.
#
# **Example 1:** \
# **Input:**\
# 1 + 1 + 1\
# **Output:**\
# Input does not contain 3 elements/Wrong operator
#
# =================
#
# **Example 2:** \
# **Input:**\
# A * B\
# **Output:**\
# Input does not contain numbers.
#
# =================
#
# **Example 3:** \
# **Input:**\
# 1 $ 3\
# **Output:**\
# Input does not contain 3 elements/Wrong operator
#
# =================
#
# **Example 4:** \
# **Input:**\
# 1 + 1\
# **Output:**\
# The answer is : 2

# %%
#To do
import operator
#creating a dictionary where operator sign is key and operator module function is value. 
operator_dict = {'+' : operator.add,'-' : operator.sub,'*' : operator.mul,'/' : operator.truediv,'%' : operator.mod}
#create a function.
def calculator (*args):
    try:
        if len(args) == 3:
            #using tuple unpacking.
            number1,operator,number2 = args
            #checking user input is digit or not with using isdigit() function.
            if number1.isdigit() and number2.isdigit():
                #convert string to integer in one-line.
                number1,number2 = int(number1),int(number2)
            else:
                #raise ValueError if checking condition return False.
                raise ValueError
                #checking operator sign in that dictionary. 
            if operator in operator_dict.keys():
                #calling dictionary's value and it is doing it's operation in one-line.
                answer = operator_dict.get(operator)(number1, number2)
            else:
                raise Exception     
        else:
            raise Exception
    #exceptions.
    except ZeroDivisionError:
        print("You cannot divided by 0.")
    except ValueError:
        print("Input does not contain numbers.")
    except Exception:
        print("Input does not contain 3 elements/Wrong operator.")
    else:
        print(f"The answer is : {answer}")
        
#taking input.       
user_input = input("Enter a number, operator and another number: ").split()
#function call.
calculator(*user_input)
# Out:
# Enter a number, operator and another number: 1 % 2
# The answer is : 1
