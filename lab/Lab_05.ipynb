# %% [markdown]
# # CSE110 Assignment 5
# This assignment is to guide you to solve everything you have learned so far by implementing functions in Python.
#
# **<font color='red'>[MUST MAINTAIN VARIABLE NAMING CONVENTIONS FOR ALL THE TASKS]</font>**
#
# ## Write the Python code of the following problems:

# %% [markdown]
# ### Task 1
# Write a function called **even_checker** that takes a number as an argument and prints whether the number is even or odd *inside the function*.
#
# **Example1:** \
# **Function Call:**\
# even_checker(5)\
# **Output:**\
# Odd!!
#
# =============================
#
# **Example2:** \
# **Function Call:**\
# even_checker(2)\
# **Output:**\
# Even!!

# %%
# to do
# implementing function
def evenChecker(numberCheck):
    #applying if-else condition to check even or odd.
    if numberCheck % 2 == 0:
        print ("Even!!")
    else:
        print ("Odd!!")
#function call.
evenChecker(5)
# Out:
# Odd!!

# %% [markdown]
# ### Task 2
# Write a python function that takes the limit as an argument of the Fibonacci series and prints till that limit.
#
# **Function Call:**\
# fibonacci(10)\
# **Output:**\
# 0 1 1 2 3 5 8\
# ======================\
# **Function Call:**\
# fibonacci(5)\
# **Output:**\
# 0 1 1 2 3 5

# %%
# to do
# implementing function
def Fibonacci(limit):
    #using one-liner.
    first_number,second_number = 0,1
    #using if-elif to check limit and print values.
    if limit == 0:
        print(first_number)
    elif limit == 1:
        print(first_number,second_number)
    else:
        print(first_number,end=" ")
        #using while-loop to check limit and restore values in variables.
        while second_number <= limit:
            print(second_number,end=" ")
            #using one-liner.
            first_number,second_number = second_number,(first_number + second_number)
#function call.
Fibonacci(5)
# Out:
# 0 1 1 2 3 5

# %% [markdown]
# ### Task 3
# Write a function called **foo_moo** that takes a number as an argument and **returns** the following statements according the below mention conditions. Then, finally prints the statement in the function call.
#
# * 	If the number is divisible by 2, it should return "Foo".
# *   If the number is divisible by 3, it should return "Moo".
# *   If the number is divisible by both 2 and 3, it should return "FooMoo".
# *   Otherwise, it returns "Boo".
#
# **Example1:** \
# **Function Call:**\
# foo_moo(5)\
# **Output:**\
# Boo
#
# =================
#
#
# **Example2:** \
# **Function Call:**\
# foo_moo(4)\
# **Output:**\
# Foo
#
# =================
#
#
# **Example3:** \
# **Function Call:**\
# foo_moo(6)\
# **Output:**\
# FooMoo

# %%
# to do
# implementing function
def fooMoo(numberCheck):
    #using if-elif condition to print following values.
    if numberCheck % 2 == 0 and numberCheck % 3 == 0:
        return "FooMoo"
    elif numberCheck % 2 == 0:
        return "Foo"
    elif numberCheck % 3 == 0:
        return "Moo"
    else:
        return "Boo"
#print & function call.
print(fooMoo(4))
# Out:
# Foo

# %% [markdown]
# ### Task 4
# Write a python function that takes a string as an argument. Your task is to calculate the number of uppercase letters and lowercase letters and print them in the function.
#
# **Function Call:**\
# function_name('The quick Sand Man')\
# **Output:**\
# No. of Uppercase characters : 3\
# No. of Lowercase Characters: 12\
# ============================\
# **Function Call:**\
# function_name('HaRRy PotteR')\
# **Output:**\
# No. of Uppercase characters : 5\
# No. of Lowercase Characters: 6

# %%
# to do
# implementing function
def function_name (string):
    upper_count,lower_count = 0,0
    #applying for-loop and ord() to check upper & lower case.
    for index in range(len(string)):
        if ord("A") <= ord(string[index]) <= ord("Z"):
            upper_count += 1
        elif ord("a") <= ord(string[index]) <= ord("z"):
            lower_count += 1
    print(f"No. of Uppercase characters : {upper_count} \nNo. of Lowercase Characters: {lower_count}")
#function call.
function_name("The quick Sand Man")
# Out:
# No. of Uppercase characters : 3
# No. of Lowercase Characters: 12

# %% [markdown]
# ### Task 5
# Write a function called **calculate_tax** that takes 3 arguments: your age, salary, and current job designation.
#
#
# Your first task is to take these arguments as user input and pass these values to the function.
#
# Your second task is to implement the function and calculate the tax as the following conditions:
# *  **NO TAX IF YOU ARE LESS THAN 18 YEARS OLD.**
# *  **NO TAX IF YOU ARE THE PRESIDENT OF THE COMPANY**
# *  No tax if you get paid less than 10,000
# *  5% tax if you get paid between 10K and 20K
# *  10% tax if you get paid more than 20K
#
#
# Finally return this tax value. Then print the returned value in the function call.
#
# **Example1:** \
# **Input:**\
# 16\
# 20000\
# Student\
# **Function Call:**\
# calculate_tax(16, 20000, 'Student')\
# **Output:**\
# 0
#
# ===================================
#
# **Example2:** \
# **Input:**\
# 20\
# 18000\
# assistant manager\
# **Function Call:**\
# calculate_tax(20, 18000, 'assistant manager')\
# **Output:**\
# 900.0
#
#
# ===================================
#
# **Example3:** \
# **Input:**\
# 20\
# 22000\
# assistant manager\
# **Function Call:**\
# calculate_tax(20, 22000, 'Assistant manager')\
# **Output:**\
# 2200.0
#
# ===================================
#
#
# **Example4:** \
# **Input:**\
# 20\
# 122000\
# president\
# **Function Call:**\
# calculate_tax(20, 122000, 'president')\
# **Output:**\
# 0
#
#
# **Hints:**\
# Here the job designation is a string, so it can be written in both uppercase and lower cases. So, you need to check the value ignoring the case.

# %%
# to do
# implementing function
def calculateTax (age,salary,current_job_designation):
    #using if-elif condition to print following values.
    if age < 18 or salary < 10000 or current_job_designation == "president":
        return (0)
    elif 10000 <= salary <= 20000:
        return ((salary/100)*5)
    elif salary > 20000:
        return ((salary/100)*10)
#input
age = int(input("Enter your age: "))
salary = int(input("Enter your salary: "))
current_job_designation = input("Enter your designation: ").lower()
#print & function call.
print(calculateTax(age,salary,current_job_designation))
# Out:
# Enter your age: 20
# Enter your salary: 18000
# Enter your designation: assistant manager
# 900.0

# %% [markdown]
# ### Task 6
# Write a function which will take 1 argument, number of days.
#
# Your first task is to take the number of days as user input and pass the value to the function.
#
# Your second task is to implement the function and calculate the total number of years, number of months, and the remaining number of days as output. No need to return any value, print inside the function.
#
# **Note:** Assume, each year to be 365 days and month to be 30 days.
#
# **Hint:** Divide and mod the main input to get the desired output.
#
# **Input:**\
# 4330\
# **Function Call:**\
# function_name(4330)\
# **Output:**\
# 11 years, 10 months and 15 days
#
# ================================
#
# **Input:**\
# 2250\
# **Function Call:**\
# function_name(2250)\
# **Output:**\
# 6 years, 2 months and 0 days
#
#
# **Hints:** \
# This task’s calculation is similar to Assignment-1’s seconds to hours, minutes conversion.

# %%
# todo
# implementing function
def function_name (days):
    #using one-liner.
    years,days = days // 365, days % 365
    months,days = days // 30, days % 30
    print(f"{years} years, {months} months and {days} days")
#input
input_days = int(input("Please give a number of days: "))
#function call.
function_name (input_days)
# Out:
# Please give a number of days: 4330
# 11 years, 10 months and 15 days

# %% [markdown]
# ### Task 7
# Write a function called **splitting_money** that takes an “amount” of money as a argument.
#
# Your first task is to take the “amount” of money as user input and pass the value to the function paramater.
#
# Your second task is to implement the function and calculate how that money can be split into 500, 100, 50, 20, 10, 5, 2, and 1 taka notes.
#
# Then print the returned value in the function call.
#
# **Example1:** \
# If the money is 1234, then the function should return
#
# "500 Taka: 2 note(s) \
# 100 Taka: 2 note(s) \
# 20 Taka: 1 note(s) \
# 10 Taka: 1 note(s) \
# 2 Taka: 2 note(s)"
#
# **Example2:** \
# If the money is 151, then the function should return
#
# "100 Taka: 1 note(s)\
# 50 Taka: 1 note(s)\
# 1 Taka: 1 note(s)"
#
#
# **Hints:** \
# This task’s calculation is similar to Assignment-1’s seconds to hours, minutes conversion. To return the result containing multiple strings, you need to store it in a variable and return it at the end of the function.

# %%
# to do
# implementing function
def splitting_money (amount):
    note_list = [500, 100, 50, 20, 10, 5, 2, 1]
    output = '"'
    for index in range(len(note_list)):
        #using one-liner.
        division_result,amount = amount//note_list[index], amount%note_list[index]
        if division_result > 0:
            if amount == 0:
                output += (f'{note_list[index]} Taka: {division_result} note(s)"')
            else:
                output += (f"{note_list[index]} Taka: {division_result} note(s)\n")
    return output
#input
input_amount = int(input("Enter total amount: "))
#print & function call.
print(splitting_money(input_amount))
# Out:
# Enter total amount: 1234
# "500 Taka: 2 note(s)
# 100 Taka: 2 note(s)
# 20 Taka: 1 note(s)
# 10 Taka: 1 note(s)
# 2 Taka: 2 note(s)"

# %% [markdown]
# ### Task 8
# Write a function called **show_palindrome** that takes a number as an argument and then returns a palindrome string. Finally, prints the returned value in the function call.
#
# **Example1:** \
# **Function Call:**\
# show_palindrome(5)\
# **Output:**\
# 123454321
#
# ===================
#
# **Example2:** \
# **Function Call:**\
# show_palindrome(3)\
# **Output:**\
# 12321

# %%
# to do
# implementing function
def show_palindrome (number):
    #using one-liner.
    counter,string = 1,""
    #applying for-loop to store strings and print.
    for count in range (1,2*number):
        if counter <= number:
            string,counter = string + str(counter), counter + 1
        else:
            number -= 1
            string += str(number)
    return(string)
#print & function call.
print(show_palindrome(3))
# Out:
# 12321

# %% [markdown]
# ### Task 9
# Write a function called **show_palindromic_triangle** that takes a number as a argument and prints a Palindromic Triangle in the function.
#
#
# **Example1:** \
# **Function Call:**\
# show_palindromic_triangle(5)\
# **Output:**
#
# &emsp; &emsp; &emsp; &emsp; 1\
# &emsp; &emsp; &emsp; 1 &nbsp; 2 &nbsp; 1 \
# &emsp; &emsp; 1 &nbsp; 2 &nbsp; 3 &nbsp; 2 &nbsp; 1 \
# &emsp; 1 &nbsp; 2 &nbsp; 3 &nbsp; 4 &nbsp; 3 &nbsp; 2 &nbsp; 1 \
# 1 &nbsp; 2 &nbsp; 3 &nbsp; 4 &nbsp; 5 &nbsp; 4 &nbsp; 3 &nbsp; 2 &nbsp; 1
#
# =============================================================
#
#
# **Example1:** \
# **Function Call:**\
# show_palindromic_triangle(3)\
# **Output:**
#
# &emsp; &emsp; 1 \
# &emsp; 1 &nbsp; 2 &nbsp; 1 \
# 1 &nbsp; 2 &nbsp; 3 &nbsp; 2 &nbsp; 1
#
#
# **Hints:** \
# Need to use both print() and print( , end = " ") functions

# %%
# to do
# implementing function
def show_palindromic_triangle(number):
    space_count = number-1
    for height in range (1,number+1):
        #using one-liner.
        counter,string = 1,""
        #applying for-loop to store strings and print.
        for count in range (1,(2*height)):
            if counter <= height:
                #using one-liner.
                string,counter = string + " " + str(counter), counter + 1
            else:
                height -= 1
                string += (" " + str(height))
        print("  "*space_count+string+"  "*space_count)
        space_count -= 1
#function call.
show_palindromic_triangle(5)
# Out:
#          1
#        1 2 1
#      1 2 3 2 1
#    1 2 3 4 3 2 1
#  1 2 3 4 5 4 3 2 1

# %%
def show_palindromic_triangle(number):
    for i in range (1,number+1):
        for j in range (1,number-i+1):
            print(" ",end="")
        for j in range (i,0,-1):
            print(j,end="")
        for j in range (2,i+1):
            print(j,end="")
        print()

show_palindromic_triangle(5)
# Out:
#     1
#    212
#   32123
#  4321234
# 543212345

# %%
def show_palindromic_triangle(number):
    for i in range (1,number+1):
        for j in range (1,number-i+1):
            print(" ",end="")
        for j in range (1,i):
            print(j,end="")
        for j in range (i,0,-1):
            print(j,end="")
        print()
show_palindromic_triangle(5)
# Out:
#     1
#    121
#   12321
#  1234321
# 123454321

# %% [markdown]
# ### Task 10
# Write a function called **area_circumference_generator** that takes a radius of a circle as a  function parameter and calculates its circumference and area. Then returns these two results as a **tuple** and prints the results using tuple unpacking in the function call accorrding to the given format. <font color='red'>[Must use tuple packing & unpacking] </font>
#
# **Example1:** \
# **Function Call:**\
# area_circumference_generator(1)\
# **Output:**\
# (3.141592653589793, 6.283185307179586)\
# Area of the circle is 3.141592653589793 and circumference is 6.283185307179586
#
# ====================================
#
# **Example2:** \
# **Function Call:**\
# area_circumference_generator(1.5)\
# **Output:**\
# (7.0685834705770345, 9.42477796076938)\
# Area of the circle is 7.0685834705770345 and circumference is 9.42477796076938
#
# ====================================
#
#
# **Example3:** \
# **Function Call:**\
# area_circumference_generator(2.5)\
# **Output:**\
# (19.634954084936208, 15.707963267948966)\
# Area of the circle is 19.634954084936208 and circumference is 15.707963267948966

# %%
# to do
# implementing function
import math
def area_circumference_generator (radius):
    #using math.pi,math.pow to calculate values.
    area = math.pi * math.pow(radius,2)
    circumference = 2 * math.pi * radius
    return (area,circumference)
#function call.
a_tuple = area_circumference_generator(1.5)
#tuple unpacking.
area,circumference = a_tuple
print(a_tuple)
print(f"Area of the circle is {area} and circumference is {circumference}")
# Out:
# (7.0685834705770345, 9.42477796076938)
# Area of the circle is 7.0685834705770345 and circumference is 9.42477796076938

# %% [markdown]
# ### Task 11
# Write a function called **make_square** that takes a tuple in the parameter as a range of numbers (starting point and ending point (included)). The function should **return a dictionary** with the numbers as keys and its squares as values.
#
# **Example1:** \
# **Function Call:**\
# make_square((1,3))\
# **Output:**\
# {1: 1, 2: 4, 3: 9}
#
# ====================================
#
# **Example2:** \
# **Function Call:**\
# make_square((5,9))\
# **Output:**\
# {5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
#
#
#
# **Hints:** \
# You need to declare a dictionary to store the result. You should use the range function to run the “for loop”.

# %%
# to do
# implementing function
def make_square (a_tuple):
    #tuple unpacking.
    starting_point,ending_point = a_tuple
    #create a empty dictionary.
    a_dict = {}
    #applying for-loop to get input numbers as keys and its squares as values.
    for key in range (starting_point,ending_point+1):
        #update the dictionary.
        a_dict.update({key:(key ** 2)})
    return a_dict
#print & function call.
print(make_square((5,9)))
# Out:
# {5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ### Task 12
# Write a function called **remove_odd** that takes a list of numbers that have both even and odd numbers mixed. \
# Your function should remove all the odd numbers and **return a compact list** which only contains the even numbers.
#
# **Example1:** \
# **Function Call:**\
# remove_odd ([21, 33, 44, 66, 11, 1, 88, 45, 10, 9])\
# **Output:**\
# [44, 66, 88, 10]
#
# ====================================
#
# **Example2:** \
# **Function Call:**\
# remove_odd ([11,2,3,4,5,2,0,5,3])\
# **Output:**\
# [2, 4, 2, 0]

# %%
# to do
# implementing function
def remove_odd (number_list):
    even_list = []
     #applying for-loop for removing odd numbers.
    for index in range (len(number_list)):
        if number_list[index] % 2 == 0:
            even_list.append(number_list[index])
    return even_list
#print & function call.
print(remove_odd([21, 33, 44, 66, 11, 1, 88, 45, 10, 9]))
# Out:
# [44, 66, 88, 10]

# %% [markdown]
# ### Task 13
# Write a function called **rem_duplicate** that takes a tuple in the parameter and return a tuple removing all the duplicate values. Then print the returned tuple in the function call.
#
# **Example1:** \
# **Function Call:**\
# rem_duplicate((1,1,1,2,3,4,5,6,6,6,6,4,0,0,0))\
# **Output:**\
# (1, 2, 3, 4, 5, 6, 0)
#
# ====================================
#
# **Example2:** \
# **Function Call:**\
# rem_duplicate(("Hi", 1, 2, 3, 3, "Hi",'a', 'a', [1,2]))\
# **Output:**\
# ('Hi', 1, 2, 3, 'a', [1, 2])
#
#
# **Hints:** \
# Unlike lists, tuples are immutable so, the tuple taken as an argument cannot be modified. But list can be modified and lastly for returning the result use type conversion. You need to use membership operators (in, not in) for preventing adding any duplicates values.

# %%
# to do
# implementing function
def rem_duplicate (a_tuple):
    new_list = []
    #applying for-loop for removing all the duplicate values.
    for index in range (len(a_tuple)):
        if a_tuple[index] not in new_list:
            new_list.append(a_tuple[index])
    return(tuple(new_list))
#print & function call.
print(rem_duplicate(("Hi", 1, 2, 3, 3, "Hi",'a', 'a', [1,2])))
# Out:
# ('Hi', 1, 2, 3, 'a', [1, 2])

# %% [markdown]
# ### Task 14
# Write a python function that takes a list as an argument. Your task is to create a new list where **each element can be present at max 2 times**. Inside the function, print the number of elements removed from the given list. Finally, return the new list and print the result.
#
# **Hint:** Use list_name.count(element) to count the total number of times an element is in a list. list_name is your new list for this problem.
#
# **Function Call:**\
# function_name([1, 2, 3, 3, 3, 3, 4, 5, 8, 8])\
# **Output:**\
# Removed: 2\
# [1, 2, 3, 3, 4, 5, 8, 8]\
# ================================\
# **Function Call:**\
# function_name([10, 10, 15, 15, 20])\
# **Output:**\
# Removed: 0\
# [10, 10, 15, 15, 20]

# %%
# todo
# implementing function
def function_name (element_list):
    new_element_list = []
    #applying for-loop and count() to find following values.
    for index in range (0,len(element_list)):
        if new_element_list.count(element_list[index]) <= 1:
            new_element_list.append(element_list[index])
    print("Removed:",len(element_list)-len(new_element_list))
    return new_element_list
#print & function call.
print(function_name([1, 2, 3, 3, 3, 3, 4, 5, 8, 8]))
# Out:
# Removed: 2
# [1, 2, 3, 3, 4, 5, 8, 8]

# %% [markdown]
# ### Task 15
# Write a function which will take 4 arguments. They are:
# - starting value(inclusive)
# - ending value(exclusive)
# - first divisor
# - second divisor
#
# Your first task is to take these arguments as user input and pass these values to the function.
#
# Your second task is to implement the function and find all the numbers that are divisible by the <u>first divisor or second divisor but not both</u> from the starting value(inclusive) and ending value(exclusive). Add all the numbers that are divisible and finally return this value. Print the returned value in the function call.
#
# **Input:**\
# 10\
# 40\
# 4\
# 7\
# **Function Call:**\
# function_name(10, 40, 4, 7)\
# **Output:**\
# 210\
# ================================\
# **Input:**\
# 5\
# 100\
# 3\
# 4\
# **Function Call:**\
# function_name(5, 100, 3, 4)\
# **Output:**\
# 2012

# %%
# to do
# implementing function
def function_name (starting_value,ending_value,first_divisor,second_divisor):
    add_values = 0
    #applying for-loop and condition to find following divisiors.
    for value in range (starting_value,ending_value):
        if (value % first_divisor == 0) != (value % second_divisor == 0):
            add_values += value
    return add_values
#input.
first_input = int(input("Enter starting value: "))
second_input = int(input("Enter ending value : "))
third_input = int(input("Enter first divisor: "))
fourth_input = int(input("Enter second divisor: "))
#print & function call.
print(function_name(first_input, second_input, third_input, fourth_input))
# Out:
# Enter starting value: 10
# Enter ending value : 40
# Enter first divisor: 4
# Enter second divisor: 7
# 210

# %%
def a_function(start_val,end_val,first_div,second_div):
    list1=[]
    total=0
    for item in range(start_val,end_val):
        if (item%first_div==0 or item%second_div==0):
            if not(item%(first_div*second_div)==0):
                list1.append(str(item))
                total=total+item
                #item+=1
    return total
start_val=int(input())
end_val=int(input())
first_div=int(input())
second_div=int(input())
print(a_function(start_val,end_val,first_div,second_div))
# Out:
# 5
# 100
# 3
# 4
# 2012

# %% [markdown]
# ### Task 16
# Write a python function that will perform the basic calculation (addition, subtraction, multiplication and division) based on 3 arguments. They are:
# - Operator ('+', '-', '/', '*')
# - First Operand (any number)
# - Second Operand (any number)
#
# Your first task is to take these arguments as user input and pass the values to the function parameters.
#
# Your second task is to write a function and performs the calculation based on the given operator. Then, finally return the result in the function call and print the result.
#
# **Input:**\
# "+"\
# 10\
# 20\
# **Function Call:**\
# function_name("+", 10, 20)\
# **Output:**\
# 30
#
# ================================
#
# **Input:**\
# "*"\
# 5.5\
# 2.5\
# **Function Call:**\
# function_name("*", 5.5, 2.5)\
# **Output:**\
# 13.75

# %%
# to do
# implementing function
def function_name (operator,first_operand,second_operand):
    #using if-elif condition to check operator and calculation.
    if operator is "+":
        return (first_operand + second_operand)
    elif operator is "-":
        return (first_operand - second_operand)
    elif operator is "/":
        return (first_operand / second_operand)
    elif operator is "*":
        return (first_operand * second_operand)
#input
first_input = input("Enter operator sign: ")
second_input = float(input("Enter first number : "))
third_input = float(input("Enter second number: "))
#print & function call.
print(function_name(first_input, second_input, third_input))
# Out:
# Enter operator sign: +
# Enter first number : 10
# Enter second number: 20
# 30.0

# %% [markdown]
# ### Task 17
# Write a python function which will take a string as an argument.
#
# Your first task is to take a string as user input and pass the value to the function.
#
# Your second task is to implement a function which will check whether all the alphabets from a to j (convert all the alphabets to lowercase) has appeared at least once in the given string or not.
# - If all of these alphabets (a to j) appear at least once, then the result will be 5.
# - If any one of the alphabets (a to j) is not in the given string, then the result will be 6.
#
# Return this result and print the statement, "Chelsea is the best club in England" that many times.
#
# **Example:**
# "A black jackal is hunting a full grown deer"
#
# Here all the alphabets from A to J are present at least once. So, the function will return 5 and will print the statement 5 times.
#
# **Input:**\
# "A black jackal is hunting a full grown deer"\
# **Function Call:**\
# function_name("A black jackal is hunting a full grown deer")\
# **Output:**\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England
#
# ==============================================
#
# **Input:**\
# "ABBCDEFEFGHI"\
# **Function Call:**\
# function_name("ABBCDEFEFGHI")\
# **Output:**\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England\
# Chelsea is the best club in England

# %%
# to do
# implementing function
def function_name (a_string):
    #using one-liner.
    letter,count = ord("a"), 0
    #applying while-loop and ord(),chr() to check every letter in sentence.
    while letter <= ord("j"):
        if chr(letter) in a_string.lower():
            count += 1
        letter += 1
    if count == 10:
        result = 5
    else:
        result = 6
    return result
#input
user_input = input("Write anything: ")
#applying for-loop to print following times.
for string_print in range (function_name(user_input)):
    #print & function call.
    print("Chelsea is the best club in England")
# Out:
# Write anything: A black jackal is hunting a full grown deer
# Chelsea is the best club in England
# Chelsea is the best club in England
# Chelsea is the best club in England
# Chelsea is the best club in England
# Chelsea is the best club in England

# %% [markdown]
# ### Task 18
# Write a function which will take 2 arguments. They are:
# - Sentence
# - position
#
# Your first task is to take these arguments as user input and pass these values to the function parameters.
#
# Your second task is to implement the function and remove the characters at the index number which is divisible by the position (Avoid the index number 0 as it will always be divisible by the position, so no need to remove the index 0 character).
# Finally, add the removed characters at the end of the new string.
#
# Return the value and then finally, print the new string at the function call.
#
# **Input:**\
# "I love programming."\
# 3\
# **Function call:**\
# function_name("I love programming.", 3)\
# **Output:**\
# I lveprgrmmngo oai.
#
# ==============================================
#
# **Input:**\
# "Python is easy to learn. I love python."\
# 6\
# **Function call:**\
# function_name("Python is easy to learn. I love python.", 6)\
# **Output:**\
# Pythonis eay to earn.I lov pythn. sl eo

# %%
# to do
# implementing function
def function_name (sentence,position):
    #using one-liner.
    updated_letters,removed_letters = sentence[0], ""
    for index in range (1,len(sentence)):
        if index % position == 0:
            removed_letters += sentence[index]
        else:
            updated_letters += sentence[index]
    return (updated_letters + removed_letters)
#input
input_sentence = input("Enter a sentence: ")
input_position = int(input("Enter position: "))
#print & function call.
print(function_name(input_sentence,input_position))
# Out:
# Enter a sentence: I love programming.
# Enter position: 3
# I lveprgrmmngo oai.

# %% [markdown]
# ### Task 19
# You have been hired as an app developer for the company karon_tumi_bekar. The company plans to make an app for a grocery store where the user can order groceries and see the total amount to be paid in the cart section.
#
# To build this feature, you have to write a function that takes 2 arguments. They are:
# - order_items (must be a list)
# - location (default value should be set to "Dhanmondi")
#
# Your first task is to take a list of items from the user. Pass the list into the function parameter along with the optional location (Use default argument technique). (Also, no need to take location as input, pass this any value you want.)
#
# Your second task is to implement the function. In the function, create a dictionary for the items shown in the table. Calculate the total price of the items passed as a list to the function. Additionally, add a delivery fee of 30 taka if the location is Dhanmondi. Otherwise, add a delivery fee of 70 taka. Finally, return the value and print it.
#
# | Item | Price(Tk) |
# | --- | --- |
# | Rice | 105 |
# | Potato | 20 |
# | Chicken | 250 |
# | Beef | 510 |
# | Oil | 85 |
#
# **Hint:** The keys are the items and values are the corresponding price. Iterate the items in the list and check if the items in the list are available in the dictionary keys or not. If it is available, add the price.
#
# **Example:**\
# function_name(["Rice", "Beef", "Rice"], "Mohakhali")
#
# total = 105 + 510 + 105 = 720 (Take the price of each item and add them.)\
# total = 720 + 70 = 790 (Finally, add the delivery fee based on the location.)
#
# **Input:**\
# ["Rice", "Beef", "Rice"]\
# **Function Call:**\
# function_name(["Rice", "Beef", "Rice"], "Mohakhali")\
# **Output:**\
# 790
#
# ==============================================
#
# **Input:**\
# ["Rice", "Beef", "Rice"]\
# **Function Call:**\
# function_name(["Rice", "Beef", "Rice"])\
# **Output:**\
# 750

# %%
# to do
# implementing function
def function_name (order_items,otder_location="Dhanmondi"):
    #using one-liner.
    items_dict,initial_price,delivery_fee ={"Rice":105,"Potato":20,"Chicken":250,"Beef":510,"Oil":85},0,30
    for index in range(len(order_items)):
        if order_items[index] in items_dict.keys():
            initial_price += items_dict[order_items[index]]
        if otder_location != "Dhanmondi":
            delivery_fee = 70
    return (initial_price + delivery_fee)
#using replace(),split() to take input as displayed and if-else condition to print as shown.
user_input = input()
items = user_input.replace("]","").replace("[","").replace('"',"").replace(" ","").split(",")
if user_input[-1] == "]":
    #print & function call.
    print(function_name(items))
else:
    items,location = items[:-1],items[-1]
    #print & function call.
    print(function_name(items,location))
# Out:
# ["Rice", "Beef", "Rice"], "Mohakhali"
# 790

# %% [markdown]
# ### Task 20
# You have been hired by the Abahani football club to write a function that will calculate the total bonus on the yearly earnings of each player for the total goals they have scored. Since the number of players will vary, you decide to use the "*args" technique that you learned in your CSE110 class. (No need to take any input from the user. Call the functions and print the values inside the function.)
# For each player: pass the name, yearly earning, the total goal scored this season, bonus percent per goal. Additionally, if the goal scored is above 30, add an extra bonus of 10000 taka. If it is between 20 and 30 inclusive, add an extra 5000 taka.
#
# **Example:**\
# function_name("Neymar", 1200000, 30, 10)
#
# bonus = 30 * (10 / 100 * 1200000) + 5000 = 3605000
#
# **Function call:**\
# function_name("Neymar", 1200000, 30, 10)\
# **Output:**\
# Neymar earned a bonus of 3605000 Taka for 30 goals.
#
# =====================================================
#
# **Function call:**\
# function_name("Neymar", 1200000, 30, 10, "Jamal", 700000, 19, 5)\
# **Output:**\
# Neymar earned a bonus of 3605000 Taka for 30 goals.\
# Jamal earned a bonus of 665000 Taka for 19 goals.

# %%
# to do
# implementing function
def function_name (*player):
    #declaring two variables
    player_data_count, print_string = 0, ""
    #applying for-loop to access players info one by one. 
    for loop_count in range(0,len(player)//4):
        #using one-liner.
        name,income,score,bonus_percentage = player[player_data_count],int(player[player_data_count+1]),int(player[player_data_count+2]),int(player[player_data_count+3])
        if 20 <= score <= 30:
            total_amount = score * (bonus_percentage / 100 * income) + 5000
        elif score>30:
            total_amount = score * (bonus_percentage / 100 * income) + 10000
        else:
            total_amount = score * (bonus_percentage / 100 * income)
        player_data_count += 4
        #using if-else condition to print as shown.
        if player_data_count == len(player):
            print_string += (f"{name} earned a bonus of {int(total_amount)} Taka for {score} goals.")
        else:
            print_string += (f"{name} earned a bonus of {int(total_amount)} Taka for {score} goals.\n")
    return print_string
#print & function call.
print(function_name("Neymar", 1200000, 30, 10, "Jamal", 700000, 19, 5))
# Out:
# Neymar earned a bonus of 3605000 Taka for 30 goals.
# Jamal earned a bonus of 665000 Taka for 19 goals.
